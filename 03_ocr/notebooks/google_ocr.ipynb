# %%
import google.generativeai as genai
from ocr.kabyle_ocr_prompt import SYSTEM_PROMPT

# Configure API key
genai.configure(api_key="AIzaSyCOTPuydUB7cWNf1j0v47QrizrK8ypdA8A")

# Initialize the model
model = genai.GenerativeModel('gemini-2.5-flash')

# Path to your LOCAL image file
filepath = 'doc/example.png'

# Upload the image file
uploaded_file = genai.upload_file(filepath)

# Generate content
#   gemini-2.5-pro
#   gemini-2.5-flash
response = model.generate_content([
    SYSTEM_PROMPT,
    uploaded_file,
])

# Save to markdown file
with open("flash.md", 'w', encoding='utf-8') as fil:
    fil.write(f'{response.text}\n')

print('Output saved to flash.md')
print("\n--- Extracted Text ---\n")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[3], line 19
#      14 uploaded_file = genai.upload_file(filepath)
#      16 # Generate content
#      17 #   gemini-2.5-pro
#      18 #   gemini-2.5-flash
# ---> 19 response = model.generate_content([
#      20     SYSTEM_PROMPT,
#      21     uploaded_file,
#      22 ])
#      24 # Save to markdown file
#      25 with open("flash.md", 'w', encoding='utf-8') as fil:
#
# File d:\Documents\py\projects\chat_aqvayli\.venv\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
# ...
